# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import Emily as ems

# %%
df = ems.cargar_dataset('HongKong_China_Data.csv')
df
# Out:
#                source    host_id   host_name  host_since host_location  \
# 0         city scrape     304876     Brendan  30/11/2010     Hong Kong
# 1     previous scrape    1300549      Darren  17/10/2011     Hong Kong
# 2         city scrape    1370155     Chuster  04/11/2011     Hong Kong
# 3         city scrape    1435069    Shanshan  23/11/2011     Hong Kong
# 4         city scrape    1443229        Shan  26/11/2011     Hong Kong
# ...               ...        ...         ...         ...           ...
# 6713      city scrape    4209137      Cherry  21/11/2012     Hong Kong
# 6714      city scrape   57341318       Edwin  04/02/2016     Hong Kong
# 6715      city scrape  667730514  James John  19/12/2024           NaN
# 6716      city scrape  280827591       Iryna  31/07/2019           NaN
# 6717      city scrape  668016531          佩涛  20/12/2024           NaN
#
#       host_response_time host_response_rate host_acceptance_rate  \
# ...

# %%
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# source                                             0
# host_id                                            0
# host_name                                          0
# host_since                                         0
# host_location                                   2287
# host_response_time                               317
# host_response_rate                               317
# host_acceptance_rate                             243
# host_is_superhost                                 77
# host_neighbourhood                               283
# host_total_listings_count                          0
# host_verifications                                 0
# host_has_profile_pic                               0
# host_identity_verified                             0
# neighbourhood                                   5040
# neighbourhood_cleansed                             0
# property_type                                      0
# room_type                                          0
# ...

# %%
backfill = ems.sustituir(df, metodo = 'bfill', valor = None)
backfill
# Out:
# c:\Users\B_3mi\Downloads\Analítica de Datos\Prof. Alfredo\Actividad_4.1\Emily.py:28: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return df.fillna(method='bfill')
#                source    host_id   host_name  host_since host_location  \
# 0         city scrape     304876     Brendan  30/11/2010     Hong Kong
# 1     previous scrape    1300549      Darren  17/10/2011     Hong Kong
# 2         city scrape    1370155     Chuster  04/11/2011     Hong Kong
# 3         city scrape    1435069    Shanshan  23/11/2011     Hong Kong
# 4         city scrape    1443229        Shan  26/11/2011     Hong Kong
# ...               ...        ...         ...         ...           ...
# 6713      city scrape    4209137      Cherry  21/11/2012     Hong Kong
# 6714      city scrape   57341318       Edwin  04/02/2016     Hong Kong
# 6715      city scrape  667730514  James John  19/12/2024           NaN
# ...

# %%
valores_nulos=bckfill.isnull().sum()
valores_nulos
# Out:
# source                                           0
# host_id                                          0
# host_name                                        0
# host_since                                       0
# host_location                                    3
# host_response_time                               4
# host_response_rate                               4
# host_acceptance_rate                             4
# host_is_superhost                                0
# host_neighbourhood                               0
# host_total_listings_count                        0
# host_verifications                               0
# host_has_profile_pic                             0
# host_identity_verified                           0
# neighbourhood                                   12
# neighbourhood_cleansed                           0
# property_type                                    0
# room_type                                        0
# ...

# %%
bckfill2 = ems.sustituir(df, metodo = 'bfill', valor = None)
bckfill2
# Out:
# c:\Users\B_3mi\Downloads\Analítica de Datos\Prof. Alfredo\Actividad_4.1\Emily.py:28: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return df.fillna(method='bfill')
#                source    host_id   host_name  host_since host_location  \
# 0         city scrape     304876     Brendan  30/11/2010     Hong Kong
# 1     previous scrape    1300549      Darren  17/10/2011     Hong Kong
# 2         city scrape    1370155     Chuster  04/11/2011     Hong Kong
# 3         city scrape    1435069    Shanshan  23/11/2011     Hong Kong
# 4         city scrape    1443229        Shan  26/11/2011     Hong Kong
# ...               ...        ...         ...         ...           ...
# 6713      city scrape    4209137      Cherry  21/11/2012     Hong Kong
# 6714      city scrape   57341318       Edwin  04/02/2016     Hong Kong
# 6715      city scrape  667730514  James John  19/12/2024           NaN
# ...

# %%
valores_nulos=bckfill2.isnull().sum()
valores_nulos
# Out:
# source                                           0
# host_id                                          0
# host_name                                        0
# host_since                                       0
# host_location                                    3
# host_response_time                               4
# host_response_rate                               4
# host_acceptance_rate                             4
# host_is_superhost                                0
# host_neighbourhood                               0
# host_total_listings_count                        0
# host_verifications                               0
# host_has_profile_pic                             0
# host_identity_verified                           0
# neighbourhood                                   12
# neighbourhood_cleansed                           0
# property_type                                    0
# room_type                                        0
# ...
